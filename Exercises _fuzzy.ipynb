# %% [markdown]
# <a href="https://colab.research.google.com/github/My-Hang/AI/blob/main/Exercises%20_fuzzy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=260a54337d208052933c15579f72aacbf7be211c2d5e26daaa20ad58a24df5fd
#   Stored in directory: /root/.cache/pip/wheels/32/2c/a1/a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# ...

# %%
#Materials Today: Proceedings
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
Windspeed= ctrl.Antecedent(np.arange(0.7,3.1,0.5),"Windspeed")
Temperature= ctrl.Antecedent(np.arange(20.4,41.5,1),'Temperature')
Rainfall= ctrl.Consequent(np.arange(0.2,10,1),'Rainfall')

Windspeed['very low']=fuzz.trimf(Windspeed.universe,[0.7,0.75,0.85])
Windspeed['low']=fuzz.trimf(Windspeed.universe,[0.8,0.95,1.1])
Windspeed['normal']=fuzz.trimf(Windspeed.universe,[1,1.6,2])
Windspeed['high']=fuzz.trimf(Windspeed.universe,[1.9,2.2,2.3])
Windspeed['very high']=fuzz.trimf(Windspeed.universe,[2.4,2.7,3.1])


Temperature['very low']= fuzz.trimf(Temperature.universe,[20.4,25,25.5])
Temperature['low']= fuzz.trimf(Temperature.universe,[25,26.5,27])
Temperature['normal']= fuzz.trimf(Temperature.universe,[28,29,31])
Temperature['high']= fuzz.trimf(Temperature.universe,[30.5,33.5,35.5])
Temperature['very high']= fuzz.trimf(Temperature.universe,[34.5,39.5,41.2])

Rainfall['very low']=fuzz.trimf(Rainfall.universe,[0.2,0.4,0.6])
Rainfall['low']=fuzz.trimf(Rainfall.universe,[0.6,1,2])
Rainfall['normal']=fuzz.trimf(Rainfall.universe,[2,3.5,4.5])
Rainfall['high']=fuzz.trimf(Rainfall.universe,[4,6,7])
Rainfall['very high']=fuzz.trimf(Rainfall.universe,[6.8,8.5,9.1])

Windspeed.view()
Rainfall.view()
Temperature.view()

rule1 =ctrl.Rule(Windspeed['very low']&Temperature['very low'],Rainfall['very low'])
rule2 =ctrl.Rule(Windspeed['very low']&Temperature['low'],Rainfall['very low'])
rule3 =ctrl.Rule(Windspeed['very low']&Temperature['normal'],Rainfall['low'])
rule4 =ctrl.Rule(Windspeed['very low']&Temperature['high'],Rainfall['normal'])
rule5 =ctrl.Rule(Windspeed['very low']&Temperature['very high'],Rainfall['normal'])

rule6 =ctrl.Rule(Windspeed['low']&Temperature['very low'],Rainfall['very low'])
rule7 =ctrl.Rule(Windspeed['low']&Temperature['low'],Rainfall['very low'])
rule8 =ctrl.Rule(Windspeed['low']&Temperature['normal'],Rainfall['very low'])
rule9 =ctrl.Rule(Windspeed['low']&Temperature['high'],Rainfall['normal'])
rule10 =ctrl.Rule(Windspeed['low']&Temperature['very high'],Rainfall['normal'])

rule11 =ctrl.Rule(Windspeed['normal']&Temperature['very low'],Rainfall['low'])
rule12 =ctrl.Rule(Windspeed['normal']&Temperature['low'],Rainfall['low'])
rule13 =ctrl.Rule(Windspeed['normal']&Temperature['normal'],Rainfall['normal'])
rule14 =ctrl.Rule(Windspeed['normal']&Temperature['high'],Rainfall['high'])
rule15 =ctrl.Rule(Windspeed['normal']&Temperature['very high'],Rainfall['high'])

rule16 =ctrl.Rule(Windspeed['high']&Temperature['very low'],Rainfall['normal'])
rule17 =ctrl.Rule(Windspeed['high']&Temperature['low'],Rainfall['normal'])
rule18 =ctrl.Rule(Windspeed['high']&Temperature['normal'],Rainfall['high'])
rule19 =ctrl.Rule(Windspeed['high']&Temperature['high'],Rainfall['very high'])
rule20 =ctrl.Rule(Windspeed['high']&Temperature['very high'],Rainfall['high'])

rule21 =ctrl.Rule(Windspeed['very high']&Temperature['very low'],Rainfall['normal'])
rule22 =ctrl.Rule(Windspeed['very high']&Temperature['low'],Rainfall['normal'])
rule23 =ctrl.Rule(Windspeed['very high']&Temperature['normal'],Rainfall['high'])
rule24 =ctrl.Rule(Windspeed['very high']&Temperature['high'],Rainfall['high'])
rule25 =ctrl.Rule(Windspeed['very high']&Temperature['very high'],Rainfall['very high'])

Rainfalling_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25])
Rainfalling= ctrl.ControlSystemSimulation(Rainfalling_ctrl)
Rainfalling.input['Windspeed']=2.8
Rainfalling.input['Temperature']=37.5
Rainfalling.compute()
print(Rainfalling.output['Rainfall'])
Rainfall.view(sim= Rainfalling)
# Out:
# 7.964041336722866

# %% [markdown]
# > Văn bản được thụt lề

# %%
#Medical System
import numpy as np 
import skfuzzy as fuzz
from skfuzzy import control as ctrl

fever = ctrl.Antecedent(np.arange(0,1,0.3), 'fever')
headache = ctrl.Antecedent(np.arange(0,1,0.3), 'headache')
nausea = ctrl.Antecedent(np.arange(0,1,0.3), 'nausea')
vomiting = ctrl.Antecedent(np.arange(0,1,0.3), 'vomiting')
jaundice = ctrl.Antecedent(np.arange(0,1,0.3), 'jaundice')
enlarge_liver = ctrl.Antecedent(np.arange(0,1,0.3), 'enlarge_liver')
joint_pain = ctrl.Antecedent(np.arange(0,1,0.3), 'joint_pain')
body_weakness = ctrl.Antecedent(np.arange(0,1,0.3), 'body_weakness')
dizziness = ctrl.Antecedent(np.arange(0,1,0.3), 'dizziness')
loss_of_appetite = ctrl.Antecedent(np.arange(0,1,0.3), 'loss_of_appetite')
mp = ctrl.Antecedent(np.arange(0,1,0.003), 'mp')
conclusion = ctrl.Consequent(np.arange(0,1,0.03), 'conclusion')


fever['mild']= fuzz.trimf(fever.universe,[0.1,0.15,0.25])
fever['moderate']= fuzz.trimf(fever.universe,[0.25,0.4,0.5])
fever['severe']= fuzz.trimf(fever.universe,[0.5,0.75,0.9])
fever['verysevere']= fuzz.trimf(fever.universe,[0.9,0.95,1])

headache['mild']= fuzz.trimf(headache.universe,[0.1,0.15,0.25])
headache['moderate']= fuzz.trimf(headache.universe,[0.25,0.4,0.5])
headache['severe']= fuzz.trimf(headache.universe,[0.5,0.75,0.9])
headache['verysevere']= fuzz.trimf(headache.universe,[0.9,0.95,1])

vomiting['mild']= fuzz.trimf(vomiting.universe,[0.1,0.15,0.25])
vomiting['moderate']= fuzz.trimf(vomiting.universe,[0.25,0.4,0.5])
vomiting['severe']= fuzz.trimf(vomiting.universe,[0.5,0.75,0.9])
vomiting['verysevere']= fuzz.trimf(vomiting.universe,[0.9,0.95,1])

jaundice['mild']= fuzz.trimf(jaundice.universe,[0.1,0.15,0.25])
jaundice['moderate']= fuzz.trimf(jaundice.universe,[0.25,0.4,0.5])
jaundice['severe']= fuzz.trimf(jaundice.universe,[0.5,0.75,0.9])
jaundice['verysevere']= fuzz.trimf(jaundice.universe,[0.9,0.95,1])

enlarge_liver['mild']= fuzz.trimf(enlarge_liver.universe,[0.1,0.15,0.25])
enlarge_liver['moderate']= fuzz.trimf(enlarge_liver.universe,[0.25,0.4,0.5])
enlarge_liver['severe']= fuzz.trimf(enlarge_liver.universe,[0.5,0.75,0.9])
enlarge_liver['verysevere']= fuzz.trimf(enlarge_liver.universe,[0.9,0.95,1])

joint_pain['mild']= fuzz.trimf(joint_pain.universe,[0.1,0.15,0.25])
joint_pain['moderate']= fuzz.trimf(joint_pain.universe,[0.25,0.4,0.5])
joint_pain['severe']= fuzz.trimf(joint_pain.universe,[0.5,0.75,0.9])
joint_pain['verysevere']= fuzz.trimf(joint_pain.universe,[0.9,0.95,1])

body_weakness['mild']= fuzz.trimf(body_weakness.universe,[0.1,0.15,0.25])
body_weakness['moderate']= fuzz.trimf(body_weakness.universe,[0.25,0.4,0.5])
body_weakness['severe']= fuzz.trimf(body_weakness.universe,[0.5,0.75,0.9])
body_weakness['verysevere']= fuzz.trimf(body_weakness.universe,[0.9,0.95,1])

dizziness['mild']= fuzz.trimf(dizziness.universe,[0.1,0.15,0.25])
dizziness['moderate']= fuzz.trimf(dizziness.universe,[0.25,0.4,0.5])
dizziness['severe']= fuzz.trimf(dizziness.universe,[0.5,0.75,0.9])
dizziness['verysevere']= fuzz.trimf(dizziness.universe,[0.9,0.95,1])

loss_of_appetite['mild']= fuzz.trimf(loss_of_appetite.universe,[0.1,0.15,0.25])
loss_of_appetite['moderate']= fuzz.trimf(loss_of_appetite.universe,[0.25,0.4,0.5])
loss_of_appetite['severe']= fuzz.trimf(loss_of_appetite.universe,[0.5,0.75,0.9])
loss_of_appetite['verysevere']= fuzz.trimf(loss_of_appetite.universe,[0.9,0.95,1])

nausea['mild']= fuzz.trimf(nausea.universe,[0.1,0.15,0.25])
nausea['moderate']= fuzz.trimf(nausea.universe,[0.25,0.4,0.5])
nausea['severe']= fuzz.trimf(nausea.universe,[0.5,0.75,0.9])
nausea['verysevere']= fuzz.trimf(nausea.universe,[0.9,0.95,1])

mp['mild']= fuzz.trimf(mp.universe,[0.1,0.15,0.25])
mp['moderate']= fuzz.trimf(mp.universe,[0.25,0.4,0.5])
mp['severe']= fuzz.trimf(mp.universe,[0.5,0.75,0.9])
mp['verysevere']= fuzz.trimf(mp.universe,[0.9,0.95,1])

conclusion['mild']= fuzz.trimf(conclusion.universe,[0.1,0.15,0.25])
conclusion['moderate']= fuzz.trimf(conclusion.universe,[0.25,0.4,0.5])
conclusion['severe']= fuzz.trimf(conclusion.universe,[0.5,0.75,0.9])
conclusion['verysevere']= fuzz.trimf(conclusion.universe,[0.9,0.95,1])

fever.view()
headache.view()
vomiting.view()
jaundice.view()
enlarge_liver.view()
joint_pain.view()
body_weakness.view()
dizziness.view()
loss_of_appetite.view()
nausea.view()
mp.view()
conclusion.view()

rule1 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['mild']&dizziness['severe']&loss_of_appetite['mild']&mp['mild'],conclusion['mild']) 
rule2 = ctrl.Rule(fever['moderate']&headache['mild']&nausea['mild']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['moderate']&body_weakness['moderate']&dizziness['severe']&loss_of_appetite['severe']&mp['moderate'],conclusion['moderate']) 
rule3 = ctrl.Rule(fever['severe']&headache['moderate']&nausea['mild']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['severe']&dizziness['mild']&loss_of_appetite['severe']&mp['moderate'],conclusion['severe']) 
rule4 = ctrl.Rule(fever['verysevere']&headache['mild']&nausea['mild']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['severe']&body_weakness['severe']&dizziness['mild']&loss_of_appetite['mild']&mp['severe'],conclusion['verysevere']) 
rule5 = ctrl.Rule(fever['moderate']&headache['mild']&nausea['mild']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['moderate']&body_weakness['moderate']&dizziness['moderate']&loss_of_appetite['severe']&mp['moderate'],conclusion['moderate']) 

rule6 = ctrl.Rule(fever['mild']&headache['moderate']&nausea['moderate']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['mild']&dizziness['moderate']&loss_of_appetite['mild']&mp['mild'],conclusion['mild']) 
rule7 = ctrl.Rule(fever['mild']&headache['mild']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['severe']&body_weakness['severe']&dizziness['moderate']&loss_of_appetite['moderate']&mp['moderate'],conclusion['severe']) 
rule8 = ctrl.Rule(fever['moderate']&headache['moderate']&nausea['moderate']&vomiting['moderate']&jaundice['moderate']&enlarge_liver['moderate']&joint_pain['moderate']&body_weakness['moderate']&dizziness['moderate']&loss_of_appetite['moderate']&mp['moderate'],conclusion['moderate']) 
rule9 = ctrl.Rule(fever['moderate']&headache['mild']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['severe']&joint_pain['moderate']&body_weakness['moderate']&dizziness['severe']&loss_of_appetite['moderate']&mp['moderate'],conclusion['moderate']) 
rule10 = ctrl.Rule(fever['mild']&headache['mild']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['moderate']&joint_pain['mild']&body_weakness['mild']&dizziness['mild']&loss_of_appetite['mild']&mp['mild'],conclusion['mild']) 

rule11 = ctrl.Rule(fever['severe']&headache['severe']&nausea['severe']&vomiting['severe']&jaundice['severe']&enlarge_liver['severe']&joint_pain['severe']&body_weakness['verysevere']&dizziness['severe']&loss_of_appetite['severe']&mp['moderate'],conclusion['verysevere']) 
rule12 = ctrl.Rule(fever['moderate']&headache['severe']&nausea['moderate']&vomiting['severe']&jaundice['moderate']&enlarge_liver['severe']&joint_pain['moderate']&body_weakness['severe']&dizziness['moderate']&loss_of_appetite['mild']&mp['moderate'],conclusion['severe']) 
rule13 = ctrl.Rule(fever['mild']&headache['moderate']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['moderate']&dizziness['mild']&loss_of_appetite['moderate']&mp['moderate'],conclusion['moderate']) 
rule14 = ctrl.Rule(fever['severe']&headache['severe']&nausea['moderate']&vomiting['severe']&jaundice['severe']&enlarge_liver['severe']&joint_pain['severe']&body_weakness['verysevere']&dizziness['moderate']&loss_of_appetite['moderate']&mp['moderate'],conclusion['severe']) 
rule15 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['severe']&dizziness['mild']&loss_of_appetite['severe']&mp['moderate'],conclusion['severe']) 

rule16 = ctrl.Rule(fever['verysevere']&headache['moderate']&nausea['mild']&vomiting['moderate']&jaundice['severe']&enlarge_liver['moderate']&joint_pain['moderate']&body_weakness['verysevere']&dizziness['severe']&loss_of_appetite['mild']&mp['moderate'],conclusion['verysevere']) 
rule17 = ctrl.Rule(fever['mild']&headache['verysevere']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['moderate']&joint_pain['mild']&body_weakness['moderate']&dizziness['verysevere']&loss_of_appetite['mild']&mp['moderate'],conclusion['verysevere']) 
rule18 = ctrl.Rule(fever['moderate']&headache['verysevere']&nausea['verysevere']&vomiting['mild']&jaundice['severe']&enlarge_liver['severe']&joint_pain['moderate']&body_weakness['severe']&dizziness['verysevere']&loss_of_appetite['verysevere']&mp['severe'],conclusion['verysevere']) 
rule19 = ctrl.Rule(fever['moderate']&headache['moderate']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['moderate']&body_weakness['moderate']&dizziness['moderate']&loss_of_appetite['moderate']&mp['moderate'],conclusion['moderate']) 
rule20 = ctrl.Rule(fever['verysevere']&headache['severe']&nausea['severe']&vomiting['severe']&jaundice['severe']&enlarge_liver['severe']&joint_pain['severe']&body_weakness['severe']&dizziness['severe']&loss_of_appetite['severe']&mp['moderate'],conclusion['verysevere']) 

conclusioning_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,
                                         rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20])
conclusioning  = ctrl.ControlSystemSimulation(conclusioning_ctrl)
conclusioning.input['fever'] = 0.1
conclusioning.input['headache'] = 0.3
conclusioning.input['nausea'] = 0.5
conclusioning.input['vomiting'] = 0.7
conclusioning.input['jaundice'] = 0.7
conclusioning.input['enlarge_liver'] = 0.7
conclusioning.input['joint_pain'] = 0.4
conclusioning.input['body_weakness'] = 0.6
conclusioning.input['dizziness'] = 0.8
conclusioning.input['loss_of_appetite'] = 0.8
conclusioning.input['mp'] = 0.5
conclusioning.compute()
print(conclusioning.output['conclusion'])
conclusion.view (sim= conclusioning)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/skfuzzy/control/controlsystem.py in defuzz(self)
#     585             try:
# --> 586                 return defuzz(ups_universe, output_mf,
#     587                               self.var.defuzzify_method)
#
# /usr/local/lib/python3.9/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     247         zero_truth_degree = mfx.sum() == 0  # Approximation of total area
# --> 248         assert not zero_truth_degree, 'Total area is zero in defuzzification!'
#     249
#
# AssertionError: Total area is zero in defuzzification!
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-9fe67d2e9910> in <module>
#     129 conclusioning.input['loss_of_appetite'] = 0.8
# ...

# %%
# Fuzzy Set
glyceamia = ctrl.Antecedent(np.arange(70,127,1),'Glyceamia')
sirolimus = ctrl.Antecedent(np.arange(0,18,0.05),'Sirolimus')
diffAce = ctrl.Antecedent(np.arange(0,19,0.05),'Diff Ace')
cyclosporine = ctrl.Antecedent(np.arange(0,21,0.05),'Cyclosporine')

gfrlevel = ctrl.Consequent(np.arange(10,19,1),'GFR Level')
proteinuria = ctrl.Consequent(np.arange(150,3655,1),'Proteinuria')
     
glyceamia['Good']=fuzz.trimf(glyceamia.universe,[70,90,100])
glyceamia['Alarm']=fuzz.trimf(glyceamia.universe,[100,125,135])
glyceamia['Danger']=fuzz.trimf(glyceamia.universe,[126,135,150])

sirolimus['Alarm Down']=fuzz.trimf(sirolimus.universe,[0,5,7])
sirolimus['Sufficient']=fuzz.trimf(sirolimus.universe,[4,7,7.5])
sirolimus['Good']=fuzz.trimf(sirolimus.universe,[6,12,15])
sirolimus['Alarm Up']=fuzz.trimf(sirolimus.universe,[11,14,16])
sirolimus['Danger']=fuzz.trimf(sirolimus.universe,[13,20,21])

diffAce['Level 0']=fuzz.trimf(diffAce.universe,[0,0,1])
diffAce['Level 1']=fuzz.trimf(diffAce.universe,[1,1.25,1.3])
diffAce['Level 2']=fuzz.trimf(diffAce.universe,[1.25,2.5,2.6])
diffAce['Level 3']=fuzz.trimf(diffAce.universe,[2.5,5,6.5])
diffAce['Level 4']=fuzz.trimf(diffAce.universe,[5,10,11])

cyclosporine['Alarm Down']=fuzz.trimf(cyclosporine.universe,[0,2,2.5])
cyclosporine['Good']=fuzz.trimf(cyclosporine.universe,[1.5,5,5.5])
cyclosporine['Sufficient']=fuzz.trimf(cyclosporine.universe,[4,11,15])
cyclosporine['Alarm Up']=fuzz.trimf(cyclosporine.universe,[8,15,20])
cyclosporine['Danger']=fuzz.trimf(cyclosporine.universe,[12,20,21])

gfrlevel['Danger']=fuzz.trimf(gfrlevel.universe,[90,95,98])
gfrlevel['Alarm 4']=fuzz.trimf(gfrlevel.universe,[60,90,100])
gfrlevel['Alarm 3']=fuzz.trimf(gfrlevel.universe,[30,60,70])
gfrlevel['Alarm 2']=fuzz.trimf(gfrlevel.universe,[15,30,50])
gfrlevel['Good']=fuzz.trimf(gfrlevel.universe,[5,14,20])

proteinuria['Good']=fuzz.trimf(proteinuria.universe,[150,150,150])
proteinuria['Sufficient']=fuzz.trimf(proteinuria.universe,[150,500,550])
proteinuria['Alterate']=fuzz.trimf(proteinuria.universe,[500,1000,1500])
proteinuria['Alarm']=fuzz.trimf(proteinuria.universe,[1000,3000,3100])
proteinuria['Danger']=fuzz.trimf(proteinuria.universe,[3000,3655,3660])

glyceamia.view()
sirolimus.view()
diffAce.view()
cyclosporine.view()
gfrlevel.view()
proteinuria.view()

     

 
#Case Study 1:Output Proteinuria 
rule_1=ctrl.Rule(glyceamia['Good']&sirolimus['Good'],proteinuria['Good'])
rule_2=ctrl.Rule(glyceamia['Danger']&sirolimus['Danger'],proteinuria['Danger'])
rule_3=ctrl.Rule(glyceamia['Good']&sirolimus['Sufficient'],proteinuria['Sufficient'])
rule_4=ctrl.Rule(glyceamia['Alarm']&sirolimus['Alarm Up'],proteinuria['Alarm'])
rule_5=ctrl.Rule(glyceamia['Alarm']&sirolimus['Sufficient'],proteinuria['Alterate'])
rule_6=ctrl.Rule(glyceamia['Good']&sirolimus['Alarm Up'],proteinuria['Alterate'])
rule_7=ctrl.Rule(glyceamia['Alarm']&sirolimus['Good'],proteinuria['Sufficient'])
rule_8=ctrl.Rule(glyceamia['Good']&sirolimus['Alarm Down'],proteinuria['Sufficient'])


rule_17=ctrl.Rule(glyceamia['Danger']&cyclosporine['Danger'],gfrlevel['Danger'])
rule_18=ctrl.Rule(glyceamia['Good']&cyclosporine['Danger'],gfrlevel['Alarm 3'])
rule_19=ctrl.Rule(glyceamia['Alarm']&cyclosporine['Alarm Up'],gfrlevel['Alarm 4'])
rule_20=ctrl.Rule(glyceamia['Good']&cyclosporine['Sufficient'],gfrlevel['Alarm 2'])
rule_21=ctrl.Rule(glyceamia['Good']&cyclosporine['Good'],gfrlevel['Good'])
rule_22=ctrl.Rule(glyceamia['Alarm']&cyclosporine['Good'],gfrlevel['Alarm 2'])
rule_23=ctrl.Rule(glyceamia['Danger']&cyclosporine['Good'],gfrlevel['Alarm 3'])


#Case 2:Output Proteinuria 
rule_9=ctrl.Rule(glyceamia['Alarm']&diffAce['Level 2'],proteinuria['Sufficient'])
rule_10=ctrl.Rule(glyceamia['Good']&diffAce['Level 1'],proteinuria['Sufficient'])
rule_11=ctrl.Rule(glyceamia['Alarm']&diffAce['Level 1'],proteinuria['Alterate'])
rule_12=ctrl.Rule(glyceamia['Danger']&diffAce['Level 1'],proteinuria['Alarm'])
rule_13=ctrl.Rule(glyceamia['Alarm']&diffAce['Level 3'],proteinuria['Alarm'])
rule_14=ctrl.Rule(glyceamia['Good']&diffAce['Level 3'],proteinuria['Alterate'])
rule_15=ctrl.Rule(glyceamia['Danger']&diffAce['Level 4'],proteinuria['Danger'])
rule_16=ctrl.Rule(glyceamia['Good']&diffAce['Level 0'],proteinuria['Good'])

rule_33=ctrl.Rule(glyceamia['Alarm']&diffAce['Level 0'],proteinuria['Sufficient'])
rule_34=ctrl.Rule(glyceamia['Danger']&diffAce['Level 0'],proteinuria['Alarm'])
rule_35=ctrl.Rule(glyceamia['Good']&diffAce['Level 2'],proteinuria['Alterate'])
rule_36=ctrl.Rule(glyceamia['Alarm']&diffAce['Level 2'],proteinuria['Sufficient'])
rule_37=ctrl.Rule(glyceamia['Danger']&diffAce['Level 2'],proteinuria['Alarm'])
rule_38=ctrl.Rule(glyceamia['Danger']&diffAce['Level 3'],proteinuria['Alarm'])
rule_39=ctrl.Rule(glyceamia['Good']&diffAce['Level 3'],proteinuria['Sufficient'])
rule_40=ctrl.Rule(glyceamia['Alarm']&diffAce['Level 4'],proteinuria['Danger'])


rule_24=ctrl.Rule(glyceamia['Good']&diffAce['Level 2'],gfrlevel['Alarm 3'])
rule_25=ctrl.Rule(glyceamia['Alarm']&diffAce['Level 2'],gfrlevel['Alarm 3'])
rule_26=ctrl.Rule(glyceamia['Good']&diffAce['Level 1'],gfrlevel['Alarm 2'])
rule_27=ctrl.Rule(glyceamia['Alarm']&diffAce['Level 1'],gfrlevel['Alarm 2'])
rule_28=ctrl.Rule(glyceamia['Good']&diffAce['Level 3'],gfrlevel['Alarm 3'])
rule_29=ctrl.Rule(glyceamia['Danger']&diffAce['Level 3'],gfrlevel['Alarm 4'])
rule_30=ctrl.Rule(glyceamia['Good']&diffAce['Level 4'],gfrlevel['Alarm 2'])
rule_31=ctrl.Rule(glyceamia['Good']&diffAce['Level 0'],gfrlevel['Good'])
rule_32=ctrl.Rule(glyceamia['Danger']&diffAce['Level 4'],gfrlevel['Danger'])


     


proteinuria_case1_ctrl=ctrl.ControlSystem([rule_1,rule_2,rule_3,rule_4,rule_5,rule_6,rule_7,rule_8])

gfrlevel_case1_ctrl=ctrl.ControlSystem([rule_17,rule_18,rule_19,rule_20,rule_21,rule_22,rule_23])

proteinuria_case2_ctrl=ctrl.ControlSystem([rule_9,rule_10,rule_11,rule_12,rule_13,rule_14,rule_15,rule_16,
                                           rule_33,rule_34,rule_35,rule_36,rule_37,rule_38,rule_39,rule_40])

gfrlevel_case2_ctrl=ctrl.ControlSystem([rule_24,rule_25,rule_26,rule_27,rule_28,rule_29,rule_30,rule_31,rule_32])
     


proteinuria_case1 = ctrl.ControlSystemSimulation(proteinuria_case1_ctrl)
proteinuria_case2 = ctrl.ControlSystemSimulation(proteinuria_case2_ctrl)
gfrlevel_case1 = ctrl.ControlSystemSimulation(gfrlevel_case1_ctrl)
gfrlevel_case2 = ctrl.ControlSystemSimulation(gfrlevel_case2_ctrl)


proteinuria_case1.input['Glyceamia']= 95
proteinuria_case1.input['Sirolimus']= 10

proteinuria_case2.input['Glyceamia']= 100
proteinuria_case2.input['Diff Ace']= 3

gfrlevel_case1.input['Glyceamia']= 125
gfrlevel_case1.input['Cyclosporine']= 4

gfrlevel_case2.input['Glyceamia']= 150
gfrlevel_case2.input['Diff Ace']=  5

proteinuria_case1.compute()
proteinuria_case2.compute()

gfrlevel_case1.compute()
gfrlevel_case2.compute()


print('Case Study 1 Proteinuria Level:',proteinuria_case1.output['Proteinuria'])
proteinuria.view(sim=proteinuria_case1)

print('Case  2 Proteinuria Level:',proteinuria_case2.output['Proteinuria'])
proteinuria.view(sim=proteinuria_case2)

print('Case Study 1 GFR Level:',gfrlevel_case1.output['GFR Level'])
gfrlevel.view(sim=gfrlevel_case1)

print('Case  2 GFR Level:',gfrlevel_case2.output['GFR Level'])
gfrlevel.view(sim=gfrlevel_case2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/skfuzzy/control/controlsystem.py in defuzz(self)
#     585             try:
# --> 586                 return defuzz(ups_universe, output_mf,
#     587                               self.var.defuzzify_method)
#
# /usr/local/lib/python3.9/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     247         zero_truth_degree = mfx.sum() == 0  # Approximation of total area
# --> 248         assert not zero_truth_degree, 'Total area is zero in defuzzification!'
#     249
#
# AssertionError: Total area is zero in defuzzification!
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-c7a9f89427b9> in <module>
#     139
#     140 gfrlevel_case1.compute()
# ...

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
height = ctrl.Antecedent(np.arange(93.5, 164, 1), 'height')
chest = ctrl.Antecedent(np.arange(49.3, 82.5, 1), 'chest')
waist = ctrl.Antecedent(np.arange(46.75, 68.25, 4), 'waist')
size = ctrl.Consequent(np.arange(5, 14 , 1), 'size')

size['small'] = fuzz.trimf(size.universe, [4, 4, 6])
size['fit'] = fuzz.trimf(size.universe, [6, 9, 13])
size['big'] = fuzz.trimf(size.universe, [11, 14, 17])

height['short'] = fuzz.trimf(height.universe, [93.5, 95, 105])
height['medium'] = fuzz.trimf(height.universe, [120, 130, 140])
height['tall'] = fuzz.trimf(height.universe, [150, 158,164])


chest['small'] = fuzz.trimf(chest.universe, [49.3, 49.5, 65])
chest['medium'] = fuzz.trimf(chest.universe, [67, 70, 75])
chest['large'] = fuzz.trimf(chest.universe, [80, 81, 82.5])

waist['small'] = fuzz.trimf(waist.universe, [46.75, 48, 52])
waist['medium'] = fuzz.trimf(waist.universe, [55, 64, 65])
waist['large'] = fuzz.trimf(waist.universe, [67, 67.5, 68.25])

rule1 = ctrl.Rule(height['short'] & chest['small'] & waist['small'], size['small'])
rule2 = ctrl.Rule(height['short'] & chest['small'] & waist['medium'], size['small'])
rule3 = ctrl.Rule(height['short'] & chest['small'] & waist['large'], size['fit'])
rule4 = ctrl.Rule(height['short'] & chest['medium'] & waist['small'], size['small'])
rule5 = ctrl.Rule(height['short'] & chest['medium'] & waist['medium'], size['fit'])
rule6 = ctrl.Rule(height['short'] & chest['medium'] & waist['large'], size['fit'])
rule7 = ctrl.Rule(height['short'] & chest['large'] & waist['small'], size['small'])
rule8 = ctrl.Rule(height['short'] & chest['large'] & waist['medium'], size['big'])
rule9 = ctrl.Rule(height['short'] & chest['large'] & waist['large'], size['fit'])
rule10 = ctrl.Rule(height['medium'] & chest['small'] & waist['small'], size['small'])
rule11 = ctrl.Rule(height['medium'] & chest['small'] & waist['medium'], size['fit'])
rule12 = ctrl.Rule(height['medium'] & chest['small'] & waist['large'], size['fit'])
rule13 = ctrl.Rule(height['medium'] & chest['medium'] & waist['small'], size['fit'])
rule14 = ctrl.Rule(height['medium'] & chest['medium'] & waist['medium'], size['fit'])
rule15 = ctrl.Rule(height['medium'] & chest['medium'] & waist['large'], size['fit'])
rule16 = ctrl.Rule(height['medium'] & chest['large'] & waist['small'], size['fit'])
rule17 = ctrl.Rule(height['medium'] & chest['large'] & waist['medium'], size['big'])
rule18 = ctrl.Rule(height['medium'] & chest['large'] & waist['large'], size['big'])
rule19 = ctrl.Rule(height['tall'] & chest['small'] & waist['small'], size['small'])
rule20 = ctrl.Rule(height['tall'] & chest['small'] & waist['medium'], size['fit'])
rule21 = ctrl.Rule(height['tall'] & chest['small'] & waist['large'], size['fit'])
rule22 = ctrl.Rule(height['tall'] & chest['medium'] & waist['small'], size['fit'])
rule23 = ctrl.Rule(height['tall'] & chest['medium'] & waist['medium'], size['fit'])
rule24 = ctrl.Rule(height['tall'] & chest['medium'] & waist['large'], size['big'])
rule25 = ctrl.Rule(height['tall'] & chest['large'] & waist['small'], size['fit'])
rule26 = ctrl.Rule(height['tall'] & chest['large'] & waist['medium'], size['big'])
rule27 = ctrl.Rule(height['tall'] & chest['large'] & waist['large'], size['big'])

size_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule9,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27])
sizing= ctrl.ControlSystemSimulation(size_ctrl)
sizing.input['height'] = 160
sizing.input['chest'] = 72
sizing.input['waist'] = 50

sizing.compute()
print(sizing.output['size'])
size.view(sim=sizing)
# Out:
# 9.439600228374347
