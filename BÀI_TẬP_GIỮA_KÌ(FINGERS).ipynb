# %% [markdown]
# <a href="https://colab.research.google.com/github/My-Hang/AI/blob/main/B%C3%80I_T%E1%BA%ACP_GI%E1%BB%AEA_K%C3%8C(FINGERS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from keras.models import Sequential
folder = '/content/drive/MyDrive/Fingers'
from google.colab import drive
drive.mount('/content/drive')
from keras.models import load_model
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
for i in range(10):
  plt.subplot(10,6,i+1)
  filename=folder+'/1loai ('+str(i+1)+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
for i in range(10):
  plt.subplot(10,6,i+1)
  filename=folder+'/2loai ('+str(i+1)+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
for i in range(10):
  plt.subplot(10,6,i+1)
  filename=folder+'/3loai ('+str(i+1)+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
for i in range(10):
  plt.subplot(10,6,i+1)
  filename=folder+'/4loai ('+str(i+1)+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
for i in range(10):
  plt.subplot(10,6,i+1)
  filename=folder+'/5loai ('+str(i+1)+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
for i in range(10):
  plt.subplot(10,6,i+1)
  filename=folder+'/6loai ('+str(i+1)+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
for i in range(10):
  plt.subplot(10,6,i+1)
  filename=folder+'/7loai ('+str(i+1)+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
for i in range(10):
  plt.subplot(10,6,i+1)
  filename=folder+'/8loai ('+str(i+1)+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
from os import listdir
from os.path import isdir
from numpy import asarray
from numpy import save
from keras.utils import load_img, img_to_array
folder = '/content/drive/MyDrive/Fingers/'
photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if file.startswith('1loai '):
    output = 1
  if file.startswith('2loai '):
    output = 2
  if file.startswith('3loai '):
    output = 3
  if file.startswith('4loai '):
    output = 4
  if file.startswith('5loai '):
    output = 5
  if file.startswith('6loai '):
    output = 6
  if file.startswith('7loai '):
    output = 7
  if file.startswith('8loai '):
    output = 8
  img =load_img(folder+file,target_size=(30,40))
  photo = img_to_array(img)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)
save('tay_photos.npy',photos)
save('tay_labels.npy',labels)
# Out:
# (80, 30, 40, 3) (80,)

# %%
import numpy as np
x_train = np.load('/content/tay_photos.npy')
y_train = np.load('/content/tay_labels.npy')
print(x_train.shape)
print(y_train.shape)
# Out:
# (80, 30, 40, 3)
# (80,)

# %%
x_train = x_train.astype('float32')/255
from keras.utils import to_categorical
y_train = to_categorical(y_train,10)
model = Sequential()

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,Normalization,LeakyReLU
from keras.optimizers import Adam

#32 lan tich chap
model = Sequential()
model.add(Conv2D(32,kernel_size = (3,3),activation = 'relu',input_shape=(30,40,3),padding='Same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Dropout(0.25))

#64 lan tich chap
model.add(Conv2D(64,(3,3),activation ='relu',padding ='same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Dropout(0.25))

#128 lan tich chap
model.add(Conv2D(128,(3,3),activation ='relu',padding ='same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64,activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(10,activation='softmax'))

from keras.losses import categorical_crossentropy
model.compile(loss = categorical_crossentropy,optimizer = Adam(),metrics=['accuracy'])
model.summary()
train = model.fit(x_train,y_train,batch_size=8,epochs = 100,verbose = 1)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_15 (Conv2D)          (None, 30, 40, 32)        896
#
#  max_pooling2d_15 (MaxPoolin  (None, 15, 20, 32)       0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 15, 20, 32)        0
#
#  conv2d_16 (Conv2D)          (None, 15, 20, 64)        18496
#
#  max_pooling2d_16 (MaxPoolin  (None, 8, 10, 64)        0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 8, 10, 64)         0
#
#  conv2d_17 (Conv2D)          (None, 8, 10, 128)        73856
#
#  max_pooling2d_17 (MaxPoolin  (None, 4, 5, 128)        0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 4, 5, 128)         0
#
#  flatten_5 (Flatten)         (None, 2560)              0
#
#  dense_10 (Dense)            (None, 64)                163904
#
#  dropout_23 (Dropout)        (None, 64)                0
#
#  dense_11 (Dense)            (None, 10)                650
#
# ...

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np
ten = {1:'Sức khỏe tốt , duyên trời tác hợp',2:'Tình duyên lận đận', 
       3:'Sức khỏe kém, tình duyên lận đận', 4:'Đào hoa',
       5:'Giàu có , đào hoa', 6:'Giàu có, tình duyên lận đận',
       7:'Nhiều tài lộc', 8:'May mắn'} 
img = load_img("/content/z4281980942037_65dfcee5839e90d1740ec8f9517c74ee.jpg",target_size=(30,40))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,30,40,3)
img = img.astype('float32')
img =img/255
result  = np.argmax(model.predict(img),axis=1)
ten[result[0]]
# Out:
# 1/1 [==============================] - 0s 258ms/step
# 'Giàu có, tình duyên lận đận'
